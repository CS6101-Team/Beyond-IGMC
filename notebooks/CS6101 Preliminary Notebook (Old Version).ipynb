# %% [markdown]
# # Git Clone and Installing of Packages

# %%
# git clone

# !git clone -b master --single-branch https://github.com/CS6101-Team/IGMC.git
# Out:
# Cloning into 'IGMC'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 413 (delta 20), reused 150 (delta 14), pack-reused 252
# Receiving objects: 100% (413/413), 64.01 MiB | 22.59 MiB/s, done.
# Resolving deltas: 100% (155/155), done.

# %%
# Change Directory

# %cd ..
# Out:
# /content/IGMC

# %%
# !nvidia-smi
# Out:
# Tue Mar  2 05:15:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python layer.py

# %%
# install packages
# torch 1.4.0

# !pip install torch==1.4.0 torchvision==0.5.0
# Out:
# Requirement already satisfied: torch==1.4.0 in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied: torchvision==0.5.0 in /usr/local/lib/python3.7/dist-packages (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.5.0) (7.0.0)

# %%
# torch-geometric 1.7.0
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install torch-geometric

# torch-geometric 1.4.2

# !pip install --no-index torch-scatter -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# !pip install --no-index torch-sparse -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# !pip install --no-index torch-cluster -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# !pip install --no-index torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# !pip install torch-geometric==1.4.2

# %% [markdown]
# # Training with Flixster

# %%
# !python Main.py --data-name flixster --epochs 0 --testing --ensemble --save-interval 1
# Out:
# Namespace(ARR=0.001, adj_dropout=0.2, batch_size=50, continue_from=None, data_appendix='', data_name='flixster', data_seed=1234, debug=False, dynamic_test=False, dynamic_train=False, dynamic_val=False, ensemble=True, epochs=0, force_undirected=False, hop=1, keep_old=False, lr=0.001, lr_decay_factor=0.1, lr_decay_step_size=50, max_nodes_per_hop=10000, max_test_num=None, max_train_num=None, max_val_num=None, multiply_by=1, no_train=False, num_relations=5, ratio=1.0, reprocess=False, sample_ratio=1.0, save_appendix='', save_interval=1, seed=1, standard_rating=False, test_freq=1, testing=True, transfer='', use_features=False, visualize=False)
# Command line input: python Main.py --data-name flixster --epochs 0 --testing --ensemble --save-interval 1
#  is saved.
# number of users =  2341
# number of item =  2956
# User features shape: (3000, 3000)
# Item features shape: (3000, 3000)
# All ratings are:
# [0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# #train: 23556, #val: 4712, #test: 2617
# Processing...
# Enclosing subgraph extraction begins...
# 100% 8/8 [00:14<00:00,  1.75s/it]
# Time elapsed for subgraph extraction: 14.2532217502594s
# Transforming to pytorch_geometric graphs...
# 100% 23556/23556 [00:01<00:00, 12432.88it/s]
# Time elapsed for transforming to pytorch_geometric graphs: 1.8950886726379395s
# Done!
# Processing...
# Enclosing subgraph extraction begins...
# 100% 8/8 [00:03<00:00,  2.66it/s]
# Time elapsed for subgraph extraction: 3.096445322036743s
# Transforming to pytorch_geometric graphs...
# 100% 2617/2617 [00:00<00:00, 10510.63it/s]
# Time elapsed for transforming to pytorch_geometric graphs: 0.24956846237182617s
# Done!
# Used #train graphs: 23556, #test graphs: 2617
# Total number of parameters is 49313
# 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "Main.py", line 428, in <module>
#     res_dir=args.res_dir
#   File "/content/IGMC/train_eval.py", line 109, in train_multiple_epochs
#     format(rmses[-1],
# IndexError: list index out of range

# %% [markdown]
# 40 epochs work but not like 1 epoch for e.g. (see movielens)

# %% [markdown]
# # Training with MovieLens100K

# %%
# !python Main.py --data-name ml_100k --save-appendix _mnph200 --data-appendix _mnph200 --epochs 80 --max-nodes-per-hop 200 --testing --ensemble --dynamic-train --save-interval 40
# Out:
# Namespace(ARR=0.001, adj_dropout=0.2, batch_size=50, continue_from=None, data_appendix='_mnph200', data_name='ml_100k', data_seed=1234, debug=False, dynamic_test=False, dynamic_train=True, dynamic_val=False, ensemble=True, epochs=80, force_undirected=False, hop=1, keep_old=False, lr=0.001, lr_decay_factor=0.1, lr_decay_step_size=50, max_nodes_per_hop='200', max_test_num=None, max_train_num=None, max_val_num=None, multiply_by=1, no_train=False, num_relations=5, ratio=1.0, reprocess=False, sample_ratio=1.0, save_appendix='_mnph200', save_interval=40, seed=1, standard_rating=False, test_freq=1, testing=True, transfer='', use_features=False, visualize=False)
# Command line input: python Main.py --data-name ml_100k --save-appendix _mnph200 --data-appendix _mnph200 --epochs 80 --max-nodes-per-hop 200 --testing --ensemble --dynamic-train --save-interval 40
#  is saved.
# Using official MovieLens split u1.base/u1.test with 20% validation...
# User features shape: (943, 23)
# Item features shape: (1682, 18)
# All ratings are:
# [1. 2. 3. 4. 5.]
# #train: 80000, #val: 16000, #test: 20000
# tcmalloc: large alloc 2070290432 bytes == 0x56353d616000 @  0x7fc403a44b6b 0x7fc403a64379 0x7fc3a6981b4a 0x7fc3a69835fa 0x7fc3a9087c44 0x7fc3f1b5a770 0x563530e63c25 0x563530e247f2 0x563530e97d75 0x563530e92e0d 0x563530e2538b 0x563530e24e99 0x563530f6c70d 0x563530edb57b 0x563530e23f41 0x563530f1599d 0x563530e97fe9 0x563530e92e0d 0x563530d64e2b 0x563530e951e6 0x563530e92b0e 0x563530e2577a 0x563530e97e50 0x563530e92e0d 0x563530e2602c 0x563530e66d39 0x563530e63c84 0x563530e248e9 0x563530e98ade 0x563530e92b0e 0x563530e92813
# Used #train graphs: 80000, #test graphs: 20000
# Total number of parameters is 52689
#   0% 0/80 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "Main.py", line 420, in <module>
#     res_dir=args.res_dir
#   File "/content/IGMC/train_eval.py", line 77, in train_multiple_epochs
#     show_progress=batch_pbar, epoch=epoch)
#   File "/content/IGMC/train_eval.py", line 160, in train
#     out = model(data)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/IGMC/models.py", line 203, in forward
#     x = torch.tanh(conv(x, edge_index, edge_type))
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/content/IGMC/layer.py", line 66, in forward
#     edge_norm=edge_norm)
#   File "/usr/local/lib/python3.7/dist-packages/torch_geometric/nn/conv/message_passing.py", line 170, in propagate
#     out = self.message(**msg_kwargs)
#   File "/content/IGMC/layer.py", line 80, in message
#     out = torch.bmm(x_j.unsqueeze(1), w).squeeze(-2)
# RuntimeError: invalid argument 7: equal number of batches expected at /pytorch/aten/src/THC/generic/THCTensorMathBlas.cu:547
#   0% 0/80 [00:01<?, ?it/s]

# %% [markdown]
# # Movielen 1million

# %%
! python Main.py --data-name ml_1m --save-appendix _mnhp100 --data-appendix _mnph100 --max-nodes-per-hop 100 --batch-size 25 --testing --epochs 40 --save-interval 5 --adj-dropout 0 --lr-decay-step-size 20 --ensemble --dynamic-train
# Out:
# Namespace(ARR=0.001, adj_dropout=0.0, batch_size=25, continue_from=None, data_appendix='_mnph100', data_name='ml_1m', data_seed=1234, debug=False, dynamic_test=False, dynamic_train=True, dynamic_val=False, ensemble=True, epochs=40, force_undirected=False, hop=1, keep_old=False, lr=0.001, lr_decay_factor=0.1, lr_decay_step_size=20, max_nodes_per_hop='100', max_test_num=None, max_train_num=None, max_val_num=None, multiply_by=1, no_train=False, num_relations=5, ratio=1.0, reprocess=False, sample_ratio=1.0, save_appendix='_mnhp100', save_interval=5, seed=1, standard_rating=False, test_freq=1, testing=True, transfer='', use_features=False, visualize=False)
# Command line input: python Main.py --data-name ml_1m --save-appendix _mnhp100 --data-appendix _mnph100 --max-nodes-per-hop 100 --batch-size 25 --testing --epochs 40 --save-interval 5 --adj-dropout 0 --lr-decay-step-size 20 --ensemble --dynamic-train
#  is saved.
# Reading processed dataset from file...
# Number of users = 6040
# Number of items = 3706
# Number of links = 1000209
# Fraction of positive links = 0.0447
# Using random dataset split ...
# All ratings are:
# [1. 2. 3. 4. 5.]
# #train: 900188, #val: 45010, #test: 100021
# Processing...
# Enclosing subgraph extraction begins...
# 100% 8/8 [03:19<00:00, 24.90s/it]
# Time elapsed for subgraph extraction: 199.60437941551208s
# Transforming to pytorch_geometric graphs...
#  84% 84158/100021 [01:38<41:32:44,  9.43s/it]^C

# %%
# !pip install wandb
# import wandb
# wandb.init()
from torch_geometric.nn import GATConv

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# flixter to douban

# %%
# with original code
# supposedly transfer with movielens model but model not available to train

# !./run_transfer_exps.sh
# Out:
# usage: Main.py [-h] [--testing] [--no-train] [--debug] [--data-name DATA_NAME]
#                [--data-appendix DATA_APPENDIX] [--save-appendix SAVE_APPENDIX]
#                [--max-train-num MAX_TRAIN_NUM] [--max-val-num MAX_VAL_NUM]
#                [--max-test-num MAX_TEST_NUM] [--seed S] [--data-seed S]
#                [--reprocess] [--dynamic-train] [--dynamic-test]
#                [--dynamic-val] [--keep-old] [--save-interval SAVE_INTERVAL]
#                [--hop S] [--sample-ratio SAMPLE_RATIO]
#                [--max-nodes-per-hop MAX_NODES_PER_HOP] [--use-features]
#                [--adj-dropout ADJ_DROPOUT] [--force-undirected]
#                [--continue-from CONTINUE_FROM] [--lr LR]
#                [--lr-decay-step-size LR_DECAY_STEP_SIZE]
#                [--lr-decay-factor LR_DECAY_FACTOR] [--epochs N]
#                [--batch-size N] [--test-freq N] [--ARR ARR]
#                [--transfer TRANSFER] [--num-relations NUM_RELATIONS]
#                [--multiply-by MULTIPLY_BY] [--visualize] [--ensemble]
#                [--standard-rating] [--ratio RATIO]
# Main.py: error: unrecognized arguments: --dynamic-dataset

# %%
# Edited (replace sh file)
# Try with flixster model
# replace dynamic dataset with dynamic test (apparently not used anywhere in Main.py)

# !./run_transfer_exps.sh flixster
# Out:
# Namespace(ARR=0.001, adj_dropout=0.2, batch_size=50, continue_from=None, data_appendix='', data_name='flixster', data_seed=1234, debug=False, dynamic_test=True, dynamic_train=False, dynamic_val=False, ensemble=True, epochs=40, force_undirected=False, hop=1, keep_old=False, lr=0.001, lr_decay_factor=0.1, lr_decay_step_size=50, max_nodes_per_hop=10000, max_test_num=None, max_train_num=None, max_val_num=None, multiply_by=1, no_train=True, num_relations=5, ratio=1.0, reprocess=False, sample_ratio=1.0, save_appendix='', save_interval=10, seed=1, standard_rating=False, test_freq=1, testing=True, transfer='results/ml_100k_mnph200_testmode/', use_features=False, visualize=False)
# Command line input: python Main.py --data-name flixster --epochs 40 --testing --no-train --ensemble --transfer results/ml_100k_mnph200_testmode/ --dynamic-test --num-relations 5 --multiply-by 1
#  is saved.
# number of users =  2341
# number of item =  2956
# User features shape: (3000, 3000)
# Item features shape: (3000, 3000)
# All ratings are:
# [0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# #train: 23556, #val: 4712, #test: 2617
# Used #train graphs: 23556, #test graphs: 2617
# Total number of parameters is 49233
# Testing begins...
# 100% 53/53 [00:03<00:00, 15.27it/s]
# Testing begins...
# 100% 53/53 [00:03<00:00, 15.40it/s]
# Testing begins...
# 100% 53/53 [00:03<00:00, 15.29it/s]
# Testing begins...
# 100% 53/53 [00:03<00:00, 15.22it/s]
# Test Once RMSE: 0.914699, Duration: 13.872483
# Ensemble test rmse is: 0.914699

# %%
# How to determine num-relations and multiply-by parameters
# !python Main.py --data-name ${data} --epochs 40 --testing --no-train --ensemble --transfer results/flixster_testmode/ --dynamic-test --num-relations ${num_relations} --multiply-by ${multiply_by}
# Out:
# usage: Main.py [-h] [--testing] [--no-train] [--debug] [--data-name DATA_NAME]
#                [--data-appendix DATA_APPENDIX] [--save-appendix SAVE_APPENDIX]
#                [--max-train-num MAX_TRAIN_NUM] [--max-val-num MAX_VAL_NUM]
#                [--max-test-num MAX_TEST_NUM] [--seed S] [--data-seed S]
#                [--reprocess] [--dynamic-train] [--dynamic-test]
#                [--dynamic-val] [--keep-old] [--save-interval SAVE_INTERVAL]
#                [--hop S] [--sample-ratio SAMPLE_RATIO]
#                [--max-nodes-per-hop MAX_NODES_PER_HOP] [--use-features]
#                [--adj-dropout ADJ_DROPOUT] [--force-undirected]
#                [--continue-from CONTINUE_FROM] [--lr LR]
#                [--lr-decay-step-size LR_DECAY_STEP_SIZE]
#                [--lr-decay-factor LR_DECAY_FACTOR] [--epochs N]
#                [--batch-size N] [--test-freq N] [--ARR ARR]
#                [--transfer TRANSFER] [--num-relations NUM_RELATIONS]
#                [--multiply-by MULTIPLY_BY] [--visualize] [--ensemble]
#                [--standard-rating] [--ratio RATIO]
# Main.py: error: argument --data-name: expected one argument

# %% [markdown]
# # Sparsity experiment skipped because there's no trained movielens model at the moment.

# %% [markdown]
# # Visualization

# %%
# !python Main.py --data-name flixster --epochs 40 --testing --no-train --visualize
# Out:
# Namespace(ARR=0.001, adj_dropout=0.2, batch_size=50, continue_from=None, data_appendix='', data_name='flixster', data_seed=1234, debug=False, dynamic_test=False, dynamic_train=False, dynamic_val=False, ensemble=False, epochs=40, force_undirected=False, hop=1, keep_old=False, lr=0.001, lr_decay_factor=0.1, lr_decay_step_size=50, max_nodes_per_hop=10000, max_test_num=None, max_train_num=None, max_val_num=None, multiply_by=1, no_train=True, num_relations=5, ratio=1.0, reprocess=False, sample_ratio=1.0, save_appendix='', save_interval=10, seed=1, standard_rating=False, test_freq=1, testing=True, transfer='', use_features=False, visualize=True)
# Command line input: python Main.py --data-name flixster --epochs 40 --testing --no-train --visualize
#  is saved.
# number of users =  2341
# number of item =  2956
# User features shape: (3000, 3000)
# Item features shape: (3000, 3000)
# All ratings are:
# [0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# #train: 23556, #val: 4712, #test: 2617
# Used #train graphs: 23556, #test graphs: 2617
# Total number of parameters is 49313
# 100% 53/53 [00:00<00:00, 103.56it/s]

# %% [markdown]
# # Download Zip file

# %%
|!zip -r /content/IGMC.zip /content/IGMC
# Out:
#   File "<ipython-input-9-1801431c11cb>", line 1
#     |!zip -r /content/IGMC.zip /content/IGMC
#     ^
# SyntaxError: invalid syntax

# %%
# from google.colab import files
# files.download("/content/IGMC.zip")
from torch_geometric.nn import SAGEConv

# %%
# !unzip /content/IGMC/100k_Movielen.zip ..
# Out:
# Archive:  /content/IGMC/100k_Movielen.zip
# caution: filename not matched:  ..

# %%
# !zip -r /content/Movie_len100k_and_transf.zip /content/IGMC/results/
# Out:
#   adding: content/IGMC/results/ (stored 0%)
#   adding: content/IGMC/results/flixster_testmode/ (stored 0%)
#   adding: content/IGMC/results/flixster_testmode/util_functions.py (deflated 75%)
#   adding: content/IGMC/results/flixster_testmode/Main.py (deflated 74%)
#   adding: content/IGMC/results/flixster_testmode/log.txt (deflated 13%)
#   adding: content/IGMC/results/flixster_testmode/models.py (deflated 82%)
#   adding: content/IGMC/results/flixster_testmode/cmd_input.txt (deflated 42%)
#   adding: content/IGMC/results/flixster_testmode/train_eval.py (deflated 73%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/ (stored 0%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint50.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint76.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint62.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint56.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/util_functions.py (deflated 75%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint12.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint32.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint26.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint66.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint8.pth (deflated 12%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint2.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint60.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint6.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint30.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint14.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint70.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/Main.py (deflated 74%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint52.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint22.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint10.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/log.txt (deflated 80%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint24.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint18.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint30.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint34.pth (deflated 12%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint46.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint68.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint42.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint74.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint78.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint28.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/models.py (deflated 82%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint38.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint22.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint46.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint64.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint48.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint70.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint26.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/cmd_input.txt (deflated 31%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint28.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint2.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint4.pth (deflated 12%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint68.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint58.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/train_eval.py (deflated 73%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint40.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint64.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint24.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint62.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint54.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint76.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint72.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint4.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint40.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint52.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint48.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint32.pth (deflated 12%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint80.pth (deflated 17%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint10.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint12.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint20.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint14.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint58.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint44.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint56.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint78.pth (deflated 16%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint36.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint6.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint42.pth (deflated 14%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint20.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint18.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint8.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint66.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint72.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint16.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint74.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint44.pth (deflated 13%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint50.pth (deflated 12%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint38.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint54.pth (deflated 15%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint36.pth (deflated 11%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint80.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint34.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/model_checkpoint60.pth (deflated 8%)
#   adding: content/IGMC/results/ml_100k_mnph200_testmode/optimizer_checkpoint16.pth (deflated 12%)
